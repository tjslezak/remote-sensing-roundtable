# %%
import os
import numpy as np
import rasterio
import xarray as xr
import hvplot.xarray
import holoviews as hv
import geoviews as gv

from rasterio.session import AWSSession
from rasterio.plot import *

hv.extension('bokeh', 'matplotlib')
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
# ...

# %%
cog_url = 's3://naip-analytic/az/2017/60cm/rgbir/31111/m_3111139_ne_12_h_20170610.mrf'

#aws = AWSSession(region_name='us-west-2', requester_pays=True)

os.environ['AWS_REQUEST_PAYER'] = 'requester'
os.environ['AWS_DEFAULT_REGION'] = 'us-west-2'
os.environ['GDAL_CACHEMAX'] = '16384'
os.environ['GDAL_DISABLE_READDIR_ON_OPEN'] = 'EMPTY_DIR'
os.environ['CPL_VSIL_CURL_ALLOWED_EXTENSIONS'] = 'TIF'
os.environ['VSI_CACHE'] = 'True'
os.environ['VSI_CACHE_SIZE'] = '100000000'

# %%
# %%time
with rasterio.open(cog_url, driver='MRF') as cog:
    coimg = xr.open_rasterio(cog, chunks={'x': 512, 'y': 512})
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# CPU times: user 22.1 ms, sys: 2.58 ms, total: 24.6 ms
# Wall time: 23.3 ms

# %%
b1 = coimg.sel(band=1).persist()

# %%
coimg[1]
# Out:
# <xarray.DataArray (y: 12559, x: 10912)>
# dask.array<shape=(12559, 10912), dtype=uint8, chunksize=(512, 512)>
# Coordinates:
#     band     int64 2
#   * y        (y) float64 3.485e+06 3.485e+06 3.485e+06 ... 3.478e+06 3.478e+06
#   * x        (x) float64 4.819e+05 4.819e+05 4.819e+05 ... 4.884e+05 4.884e+05
# Attributes:
#     transform:   (0.6000000000000011, 0.0, 481882.8, 0.0, -0.5999999999999925...
#     crs:         +init=epsg:26912
#     res:         (0.6000000000000011, 0.5999999999999925)
#     is_tiled:    1
#     nodatavals:  (nan, nan, nan, nan)

# %%
# %%time
show(coimg[1])
# Out:
# CPU times: user 7.33 s, sys: 1.34 s, total: 8.67 s
# Wall time: 4.94 s

# %%
# %%time
with rasterio.open(cog_url, driver='MRF') as cog:
    nir = cog.read((4,2,3))
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# CPU times: user 23.3 s, sys: 2.19 s, total: 25.5 s
# Wall time: 1min 5s

# %%
coimg.compute()
# Out:
# <xarray.DataArray (band: 4, y: 12559, x: 10912)>
# array([[[149, 126, ..., 118,  71],
#         [164, 130, ...,  90,  82],
#         ...,
#         [114, 108, ...,  54,  53],
#         [ 97,  81, ...,  41,  43]],
#
#        [[129,  98, ..., 106,  64],
#         [138, 106, ...,  83,  89],
#         ...,
#         [101,  90, ...,  52,  43],
#         [ 85,  76, ...,  38,  47]],
#
#        [[109,  88, ...,  89,  63],
#         [115,  90, ...,  66,  68],
#         ...,
#         [ 89,  81, ...,  56,  47],
#         [ 78,  65, ...,  41,  42]],
#
#        [[128, 119, ..., 121,  93],
#         [144, 128, ..., 126, 124],
#         ...,
#         [105, 108, ...,  68,  57],
#         [109, 133, ...,  56,  76]]], dtype=uint8)
# Coordinates:
#   * band     (band) int64 1 2 3 4
#   * y        (y) float64 3.485e+06 3.485e+06 3.485e+06 ... 3.478e+06 3.478e+06
#   * x        (x) float64 4.819e+05 4.819e+05 4.819e+05 ... 4.884e+05 4.884e+05
# Attributes:
# ...

# %%
# %%time
show(nir)
# Out:
# CPU times: user 7.67 s, sys: 1.17 s, total: 8.84 s
# Wall time: 8.01 s

# %%
image_url = 's3://naip-source/az/2017/60cm/rgbir/31111/m_3111139_ne_12_h_20170610.tif'

# %%
# %%time
with rasterio.open(image_url) as image_src:
    da = xr.open_rasterio(image_src, chunks={'x': 512, 'y': 512})
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# CPU times: user 23.3 ms, sys: 2.91 ms, total: 26.3 ms
# Wall time: 24.5 ms

# %%
show(da[1])

# %%
cog_url = 's3://naip-analytic/az/2017/60cm/rgbir/31111/m_3111139_ne_12_h_20170610.mrf'

aws = AWSSession(region_name='us-west-2', requester_pays=True)

os.environ['AWS_REQUEST_PAYER'] = 'requester'
os.environ['AWS_DEFAULT_REGION'] = 'us-west-2'
# os.environ['GDAL_DISABLE_READDIR_ON_OPEN'] = 'EMPTY_DIR'
# os.environ['CPL_VSIL_CURL_ALLOWED_EXTENSIONS'] = 'TIF'
# os.environ['VSI_CACHE'] = 'True'

with rasterio.Env(aws), rasterio.open(cog_url, driver='MRF') as cog:
    cog_da = xr.open_rasterio(cog, chunks={'x': 512, 'y': 512})
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials

# %%
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials

# %%
# %%time
show(cog_da[1])
# Out:
# CPU times: user 14.4 s, sys: 1.57 s, total: 15.9 s
# Wall time: 28.3 s

# %%
cog_url = 's3://naip-analytic/az/2017/60cm/rgbir/31111/m_3111139_ne_12_h_20170610.mrf'

os.environ['AWS_REQUEST_PAYER'] = 'requester'
os.environ['GDAL_DISABLE_READDIR_ON_OPEN']='EMPTY_DIR'
os.environ['CPL_VSIL_CURL_ALLOWED_EXTENSIONS']='TIF'
os.environ['VSI_CACHE'] = 'True'

# %%
with rasterio.open(cog_url, driver='MRF') as cog:
    cog_da = xr.open_rasterio(cog)
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials

# %%
# %%time
show(cog_da[1])
# Out:
# CPU times: user 6.45 s, sys: 1.06 s, total: 7.5 s
# Wall time: 4.26 s

# %%
cog_url = 's3://naip-analytic/az/2017/60cm/rgbir/31111/m_3111139_ne_12_h_20170610.mrf'

os.environ['AWS_REQUEST_PAYER'] = 'requester'
os.environ['GDAL_DISABLE_READDIR_ON_OPEN']='EMPTY_DIR'
os.environ['CPL_VSIL_CURL_ALLOWED_EXTENSIONS']='TIF'
os.environ['VSI_CACHE'] = 'True'

# %%
with rasterio.open(cog_url, driver='MRF') as cog:
    cda = xr.open_rasterio(cog, chunks={'x': 512, 'y': 512})
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials

# %%
# %%time
show(cda[1])
# Out:
# CPU times: user 6.91 s, sys: 1.32 s, total: 8.24 s
# Wall time: 4.76 s

# %%
cda
# Out:
# <xarray.DataArray (band: 4, y: 12559, x: 10912)>
# dask.array<shape=(4, 12559, 10912), dtype=uint8, chunksize=(4, 512, 512)>
# Coordinates:
#   * band     (band) int64 1 2 3 4
#   * y        (y) float64 3.485e+06 3.485e+06 3.485e+06 ... 3.478e+06 3.478e+06
#   * x        (x) float64 4.819e+05 4.819e+05 4.819e+05 ... 4.884e+05 4.884e+05
# Attributes:
#     transform:   (0.6, 0.0, 481882.8, 0.0, -0.6, 3485331.6)
#     crs:         +init=epsg:26912
#     res:         (0.6, 0.6)
#     is_tiled:    0
#     nodatavals:  (nan, nan, nan, nan)

# %%
cog_da
# Out:
# <xarray.DataArray (band: 4, y: 12559, x: 10912)>
# [548175232 values with dtype=uint8]
# Coordinates:
#   * band     (band) int64 1 2 3 4
#   * y        (y) float64 3.485e+06 3.485e+06 3.485e+06 ... 3.478e+06 3.478e+06
#   * x        (x) float64 4.819e+05 4.819e+05 4.819e+05 ... 4.884e+05 4.884e+05
# Attributes:
#     transform:   (0.6000000000000011, 0.0, 481882.8, 0.0, -0.5999999999999925...
#     crs:         +init=epsg:26912
#     res:         (0.6000000000000011, 0.5999999999999925)
#     is_tiled:    1
#     nodatavals:  (nan, nan, nan, nan)

# %%
cog_da2
# Out:
# <xarray.DataArray (band: 4, y: 12559, x: 10912)>
# dask.array<shape=(4, 12559, 10912), dtype=uint8, chunksize=(4, 512, 512)>
# Coordinates:
#   * band     (band) int64 1 2 3 4
#   * y        (y) float64 3.485e+06 3.485e+06 3.485e+06 ... 3.478e+06 3.478e+06
#   * x        (x) float64 4.819e+05 4.819e+05 4.819e+05 ... 4.884e+05 4.884e+05
# Attributes:
#     transform:   (0.6000000000000011, 0.0, 481882.8, 0.0, -0.5999999999999925...
#     crs:         +init=epsg:26912
#     res:         (0.6000000000000011, 0.5999999999999925)
#     is_tiled:    1
#     nodatavals:  (nan, nan, nan, nan)

# %%
# %%time
with rasterio.open(image_url) as image_src:
    img = image_src.read((4,2,3))
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# CPU times: user 22.3 s, sys: 2.74 s, total: 25.1 s
# Wall time: 1min 18s

# %%
# %%time
with rasterio.open(image_url) as image_src:
    da = xr.open_rasterio(image_src, chunks={'x': 512, 'y': 512})
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# CPU times: user 22 ms, sys: 3.05 ms, total: 25.1 ms
# Wall time: 23.2 ms

# %%
# %%time
with rasterio.open(image_url) as image_src:
    img = image_src.read((4,2,3))
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# CPU times: user 21.8 s, sys: 2.87 s, total: 24.7 s
# Wall time: 1min 9s

# %%
# %matplotlib inline
show(img)

# %%
da.hvplot(rasterize=True, dynamic=True, width=800, height=800)

# %%
show(da[1])

# %%
cog_url = 's3://naip-analytic/az/2017/60cm/rgbir/31111/m_3111139_ne_12_h_20170610.mrf'

os.environ["AWS_REQUEST_PAYER"] = "requester"

# %%
# %%time
with rasterio.open(cog_url, driver='MRF') as cog:
    cog_da = xr.open_rasterio(cog)
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# rasterio/_shim.pyx in rasterio._shim.open_dataset()
#
# rasterio/_err.pyx in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/vsis3/naip-analytic/az/2017/60cm/rgbir/31111/m_3111139_ne_12_h_20170610.mrf' does not exist in the file system, and is not recognized as a supported dataset name.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/anaconda3/lib/python3.7/site-packages/rasterio/env.py in wrapper(*args, **kwds)
#     400
#     401         with env_ctor(session=session):
# --> 402             return f(*args, **kwds)
#     403
# ...

# %%
# %%time
with rasterio.open(cog_url, driver='MRF') as cog:
    cog_img = cog.read((4,2,3))
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# rasterio/_shim.pyx in rasterio._shim.open_dataset()
#
# rasterio/_err.pyx in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/vsis3/naip-analytic/az/2017/60cm/rgbir/31111/m_3111139_ne_12_h_20170610.mrf' does not exist in the file system, and is not recognized as a supported dataset name.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/anaconda3/lib/python3.7/site-packages/rasterio/env.py in wrapper(*args, **kwds)
#     400
#     401         with env_ctor(session=session):
# --> 402             return f(*args, **kwds)
#     403
# ...

# %%
gv.tile_sources.ESRI * cog_da.hvplot(rasterize=True, dynamic=True, width=800, height=800)

# %%
cog.block_shapes

# %%
da

# %%
cog.transform

# %%
da.transform
